# %%
import warnings 
warnings.filterwarnings("ignore", category=FutureWarning)

import pandas  as  pd
import numpy as np
df3 = pd.read_csv('/auto_home/tshaqura/Documents/Data Project/Data_clean.csv',sep="\t", header=None, encoding="utf8")
display(df3)
# Out:
#                                                       0
# 0     obviously made show famous 1950s stripper mist...
# 1     film effective persuading zionist conspiracy m...
# 2     unless already familiar pop stars star film sa...
# 3     around time europe began fighting world war ii...
# 4     im surprised even cowgirls get blues movie any...
# 5     fortyeight two hundred and seventyeight people...
# 6     went watch movie expecting nothing really much...
# 7     good cast best given story makes sense charact...
# 8     thing kept vomiting seeing movie fact actors f...
# 9     watched film fifteen minutes ago still idea wa...
# 10    two reasons give one movie one reason actors l...
# 11    man attic movie set 1910s inspired true story ...
# 12    sleepless night switching channels found embar...
# 13    basically watching something nt make sense spo...
# 14    dumbfounded actually sat watched love independ...
# 15    otherwise good review loleralacartelort7890 sa...
# ...
